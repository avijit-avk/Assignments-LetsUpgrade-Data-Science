# %% [markdown]
# <a href="https://colab.research.google.com/github/avijit-avk/Assignments-LetsUpgrade-Data-Science/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Task 1**
#
#
#
# reading the dataset

# %%
#importing the dataset

url = 'https://raw.githubusercontent.com/avijit-avk/Assignments-LetsUpgrade-Data-Science/main/pubg.csv'
df1 = pd.read_csv(url)
df1
# Out:
#                   Id         groupId  ... winPoints  winPlacePerc
# 0     2f262dd9795e60  78437bcd91d40e  ...      1470        0.0000
# 1     a32847cf5bf34b  85b7ce5a12e10b  ...      1531        0.2222
# 2     1b1900a9990396  edf80d6523380a  ...         0        0.8571
# 3     f589dd03b60bf2  804ab5e5585558  ...         0        0.3462
# 4     c23c4cc5b78b35  b3e2cd169ed920  ...      1557        0.0690
# ...              ...             ...  ...       ...           ...
# 9995  ef4f474acd8e85  2eca2a8391f75d  ...      1471        0.8333
# 9996  cf0bf82fb4d80e  2eaf2765f93adb  ...      1500        0.7174
# 9997  a0a31a0b1dcbe1  8d50c64ccc5071  ...      1434        0.2083
# 9998  f6874657399d69  d31843d7e62ccb  ...      1534        0.2449
# 9999  90359b0b8f8b0d  61d5b1bb8da43f  ...         0        0.1875
#
# [10000 rows x 29 columns]

# %% [markdown]
# # **Task 2**
#
#
# Checking the data type of columns

# %%
data_type = df1.dtypes
data_type
# Out:
# Id                  object
# groupId             object
# matchId             object
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %% [markdown]
# # **Task 3**
#
#
# Finding summary of all the numerical columns and write the findings about it.

# %%
num_summary = df1.describe()
num_summary
# Out:
#             assists        boosts  ...   winPoints  winPlacePerc
# count  10000.000000  10000.000000  ...  10000.0000  10000.000000
# mean       0.234600      1.088500  ...    609.3440      0.469926
# std        0.575149      1.703279  ...    739.7924      0.304508
# min        0.000000      0.000000  ...      0.0000      0.000000
# 25%        0.000000      0.000000  ...      0.0000      0.200000
# 50%        0.000000      0.000000  ...      0.0000      0.458300
# 75%        0.000000      2.000000  ...   1495.0000      0.735100
# max        7.000000     18.000000  ...   1863.0000      1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
#         The mean, min, max, std, count for all numercial column in the dataframe has been displayed.

# %% [markdown]
# # **Task 4**
#
#
# The average person kills how many players?

# %%
avg = df1['kills'].mean()
print("\nThe average person kills :", avg,"player")
# Out:
# The average person kills : 0.9134 player

# %% [markdown]
# # **Task - 5**
#
#
# 99% of people have how many kills?

# %%
kills_per = df1["kills"].quantile(0.99)
print("\n99% of people have",kills_per,"kills")
# Out:
# 99% of people have 7.0 kills

# %% [markdown]
# # **Task - 6**
#
#
#
# The most kills ever recorded are how much?

# %%
most_kill = df1["kills"].max()
print("\nThe most kill ever recorded are :",most_kill)
# Out:
# The most kill ever recorded are : 35

# %% [markdown]
# # **Task - 7**
#
#
#
# Print all the columns of the dataframe.

# %%
df1.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %% [markdown]
# # **Task - 8**
#
#
#
# Comment on distribution of the match's duration. Use seaborn.

# %%
sns.distplot( df1['matchDuration'] );
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
#       Match duration is mostly high during 1250 to 1500

# %% [markdown]
# # **Task - 9**
#
#
#
# Comment on distribution of the walk distance. Use seaborn

# %%
sns.distplot( df1['walkDistance'] );
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
#         Most of the walking distance lies between 0 to 2000

# %% [markdown]
# # **Task - 10**
#
#
#
# Plot distribution of the match's duration vs walk distance one below the other.

# %%
# %matplotlib inline
plt.style.use('classic')
plt.figure()

# plotting matchDuration
plt.subplot(2,1,1)
plt.plot(df1["matchDuration"],"-")
plt.xlabel("Match Duration")

# plotting walkDistance
plt.subplot(2,1,2)
plt.plot(df1["walkDistance"],"--")
plt.xlabel("Walk Distance")
# Out:
# Text(0.5, 0, 'Walk Distance')

# %% [markdown]
# # **Task - 11**
#
#
#
# Plot distribution of the match's duration vs walk distance side by side.

# %%
# %matplotlib inline
plt.style.use('classic')
plt.figure(figsize=(10,5))

# ploting match Duration
plt.subplot(1,2,1)
plt.plot(df1["matchDuration"])
plt.xlabel("Match Duration")

# ploting  walk Distance
plt.subplot(1,2,2)
plt.plot(df1["walkDistance"])
plt.xlabel("Walk Distance")
# Out:
# Text(0.5, 0, 'Walk Distance')

# %% [markdown]
# # **Task - 12**
#
#
#
#
# Pairplot the dataframe. Comment on kills vs damage dealt, Comment on maxPlace vs numGroups.

# %%
sns.pairplot(df1.head(1000));

# %% [markdown]
# # **Task - 13**
#
#
#
# How many unique values are there in 'matchType' and what are their counts?

# %%
uni = pd.unique(df1['matchType'])
print("\nUnique value in \"matchType\" is :",uni)
len_uni = len(uni)
print("\nCount of unique value in matchType is :",len_uni)
# Out:
# Unique value in "matchType" is : ['squad-fpp' 'squad' 'duo-fpp' 'solo-fpp' 'duo' 'solo' 'crashfpp'
#  'flaretpp' 'normal-squad-fpp' 'normal-duo-fpp' 'flarefpp' 'normal-squad'
#  'normal-solo-fpp' 'crashtpp']
#
# Count of unique value in matchType is : 14

# %% [markdown]
# # **Task - 14**
#
#
# Plot a barplot of ‘matchType’ vs 'killPoints'. Write your inferences.

# %%
sns.barplot(df1['matchType'],df1['killPoints']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Task - 15**
#
# Plot a barplot of ‘matchType’ vs ‘weaponsAcquired’. Write your inferences.

# %%
sns.barplot(df1['matchType'],df1['weaponsAcquired']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Task - 16**
#
# Find the Categorical columns.

# %%
cat_col = df1.select_dtypes('category').columns 
cat_col
# Out:
# Index([], dtype='object')

# %% [markdown]
# # **Task - 17**
#
# Plot a boxplot of ‘matchType’ vs ‘winPlacePerc’. Write your inferences.

# %%
sns.boxplot(x='matchType', y='winPlacePerc', data=df1);

# %% [markdown]
# # **Task - 18**
#
# Plot a boxplot of ‘matchType’ vs ‘matchDuration’. Write your inferences.

# %%
sns.boxplot(x='matchType', y='matchDuration', data=df1);

# %% [markdown]
# # **Task - 19**
#
# Change the orientation of the above plot to horizontal.

# %%
sns.boxplot( x='matchDuration', y='matchType',data=df1);

# %% [markdown]
# # **Task - 20**
#
# Add a new column called ‘KILL’ which contains the sum of following columns viz. headshotKills, teamKills, roadKills.

# %%
df1['KILL'] = df1['headshotKills'] + df1['teamKills'] + df1['roadKills']
df1['KILL']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: KILL, Length: 10000, dtype: int64

# %% [markdown]
# # **Task - 21**
#
# Round off column ‘winPlacePerc’ to 2 decimals.

# %%
df1['winPlacePerc'].round(decimals=2)
# Out:
# 0       0.00
# 1       0.22
# 2       0.86
# 3       0.35
# 4       0.07
#         ...
# 9995    0.83
# 9996    0.72
# 9997    0.21
# 9998    0.24
# 9999    0.19
# Name: winPlacePerc, Length: 10000, dtype: float64

# %% [markdown]
# # **Task - 22**
#
# Take a sample of size 50 from the column damageDealt for 100 times and calculate its mean. Plot it on a histogram and comment on its distribution.

# %%
mean = []

for i in range(100):
  
  for x in range(0,1001,50):
    
    mean1 = df1['damageDealt'].head(x).mean()
    mean.append(mean1)
 
sns.histplot(data=df1['damageDealt'], x=mean)
